# %%
# %load_ext autoreload
# %autoreload 2

import yaml
import torch
import matplotlib.pyplot as plt

# %%
config_file = './configs/lego.yaml'
with open(config_file, 'r') as file:
    config = yaml.safe_load(file)

# %%
from utils.DataLoaderLego import DataLoaderLego

data_loader = DataLoaderLego(config['data'])

images, poses, focal = data_loader.getDataset('train')

# %%
from utils.Camera import Camera

cameras = []
H, W = images[0].shape[:2] # proBABLY SWAPED

for i in range(images.shape[0]):
    cameras.append(Camera(H, W, poses[i], focal, 'cuda'))

# %%
from utils.Renderer import Renderer

renderer = Renderer(config['renderer'])

r1, r2 = cameras[0].getRays()
r1 = r1.expand(r2.shape)

print(r1.device)

points, dists = renderer.getSparsePoints(r1,r2)

points = points.reshape((-1,) + points.shape[2:])
dists = dists.reshape((-1, ) + dists.shape[2:])
# Out:
# cpu

# %%
from models.TinyNerf import TinyNerf

model = TinyNerf(6)
device = 'cpu'
if torch.cuda.is_available():
    device = torch.cuda.current_device()
model = model.to(device)
# Out:
# 6

# %%
# %load_ext autoreload
# %autoreload 2

from utils.TrainerTinyNerf import TrainerTinyNerf
import imageio.v3 as iio

test_img = "nerf_synthetic/lego/val/r_0.png"
test_img = iio.imread(test_img)[:,:,:3]
test_img = torch.tensor(test_img)
test_img = torch.nn.functional.interpolate(test_img[None,...].permute(
            0, 3, 1, 2), (100, 100), mode='bilinear', align_corners=False).permute(0, 2, 3, 1)[0]
test_img = test_img/255

test_pose = torch.tensor([
                [
                    -0.963964581489563,
                    -0.2611401677131653,
                    0.0507759265601635,
                    0.2046843022108078
                ],
                [
                    0.26603081822395325,
                    -0.9462433457374573,
                    0.18398693203926086,
                    0.7416750192642212
                ],
                [
                    7.450580596923828e-09,
                    0.1908649355173111,
                    0.9816163182258606,
                    3.957021951675415
                ],
                [
                    0.0,
                    0.0,
                    0.0,
                    1.0
                ]
            ])

#test_pose = test_pose.to('cuda')
#test_img = test_img.to('cuda')

trainer = TrainerTinyNerf(model, device, images, cameras, renderer, config['trainer'])
trainer.train(test_img[None,...], test_pose[None,...], focal)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 6
# Epoch: 0, Loss: 0.12017347663640976
# Test PSNR: 7.230343818664551
# torch.Size([10000, 3])
# Epoch: 10, Loss: 0.14987099170684814
# Test PSNR: 9.03034782409668
# torch.Size([10000, 3])
# Epoch: 20, Loss: 0.06223681569099426
# Test PSNR: 10.608988761901855
# torch.Size([10000, 3])
# Epoch: 30, Loss: 0.04696773737668991
# Test PSNR: 11.461618423461914
# torch.Size([10000, 3])
# Epoch: 40, Loss: 0.10395799577236176
# Test PSNR: 11.393438339233398
# torch.Size([10000, 3])
# Epoch: 50, Loss: 0.09376884996891022
# Test PSNR: 11.436334609985352
# torch.Size([10000, 3])
# Epoch: 60, Loss: 0.0573839396238327
# Test PSNR: 11.575852394104004
# torch.Size([10000, 3])
# Epoch: 70, Loss: 0.04342098534107208
# Test PSNR: 11.5720853805542
# torch.Size([10000, 3])
# Epoch: 80, Loss: 0.11048095673322678
# Test PSNR: 11.58206558227539
# torch.Size([10000, 3])
# Epoch: 90, Loss: 0.06854972243309021
# Test PSNR: 11.560954093933105
# torch.Size([10000, 3])
# Epoch: 100, Loss: 0.05893705040216446
# Test PSNR: 11.504925727844238
# torch.Size([10000, 3])
# Epoch: 110, Loss: 0.08584031462669373
# Test PSNR: 11.567034721374512
# torch.Size([10000, 3])
# Epoch: 120, Loss: 0.04937911033630371
# Test PSNR: 11.50522232055664
# torch.Size([10000, 3])
# Epoch: 130, Loss: 0.04686622694134712
# Test PSNR: 11.603446006774902
# torch.Size([10000, 3])
# Epoch: 140, Loss: 0.03952627629041672
# Test PSNR: 11.484427452087402
# torch.Size([10000, 3])
# Epoch: 150, Loss: 0.115946926176548
# Test PSNR: 11.557312965393066
# torch.Size([10000, 3])
# Epoch: 160, Loss: 0.027551395818591118
# Test PSNR: 11.624387741088867
# torch.Size([10000, 3])
